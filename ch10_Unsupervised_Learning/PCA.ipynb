# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_us_arrests = pd.read_csv("../data/USArrests.csv")

# %%
df_us_arrests.head(n=10)
# Out:
#     Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0      Alabama    13.2      236        58  21.2
# 1       Alaska    10.0      263        48  44.5
# 2      Arizona     8.1      294        80  31.0
# 3     Arkansas     8.8      190        50  19.5
# 4   California     9.0      276        91  40.6
# 5     Colorado     7.9      204        78  38.7
# 6  Connecticut     3.3      110        77  11.1
# 7     Delaware     5.9      238        72  15.8
# 8      Florida    15.4      335        80  31.9
# 9      Georgia    17.4      211        60  25.8

# %%
corr = df_us_arrests.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0882ff9c_aef3_11e9_afc6_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0882ff9c_aef3_11e9_afc6_acde48001122row0_col1 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_0882ff9c_aef3_11e9_afc6_acde48001122row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0882ff9c_aef3_11e9_afc6_acde48001122row0_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_0882ff9c_aef3_11e9_afc6_acde48001122row1_col0 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_0882ff9c_aef3_11e9_afc6_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0882ff9c_aef3_11e9_afc6_acde48001122row1_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
# ...
